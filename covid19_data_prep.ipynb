# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta,date
import matplotlib.pyplot as plt
import folium
import plotly.express as px
from matplotlib import ticker 
from scipy.interpolate import make_interp_spline, BSpline
import pycountry_convert as pc
#import geopandas as gpd

# %% [markdown]
# ## Interactive web-based dashboard https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6
#
# ## COVID-19 Data Repository by the Center for Systems Science and Engineering (CSSE) at Johns Hopkins University
# ### https://github.com/CSSEGISandData/COVID-19/

# %% [markdown]
# ### Get Data

# %%
# Retriving Dataset from 
# https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data
# which is updated daily

url_confirmed = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
df_confirmed = pd.read_csv( url_confirmed )

url_death = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"
df_deaths = pd.read_csv( url_death )

url_recovered = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv"
df_recovered = pd.read_csv(url_recovered)
 
#url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv"
#df_confirmed_US = pd.read_csv( url )

# %%
df_confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  9/25/20  9/26/20  9/27/20  \
# 0        0        0        0        0  ...    39186    39192    39227
# 1        0        0        0        0  ...    13045    13153    13259
# 2        0        0        0        0  ...    50754    50914    51067
# 3        0        0        0        0  ...     1836     1836     1836
# 4        0        0        0        0  ...     4590     4672     4718
#
#    9/28/20  9/29/20  9/30/20  10/1/20  10/2/20  10/3/20  10/4/20
# 0    39233    39254    39268    39285    39290    39297    39341
# 1    13391    13518    13649    13806    13965    14117    14266
# 2    51213    51368    51530    51690    51847    51995    52136
# 3     1966     1966     2050     2050     2110     2110     2110
# 4     4797     4905     4972     5114     5211     5370     5402
#
# [5 rows x 261 columns]

# %%
# Check the size of the each of the three dataframe
print(df_confirmed.shape)
print(df_deaths.shape)
print(df_recovered.shape)
# Out:
# (266, 261)
# (266, 261)
# (253, 261)

# %%
# The recovered dataframe has less rows, because there is only one row for Canada, no data on Province/State level
df_recovered[df_recovered["Country/Region"]=='Canada']
# Out:
#    Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 39            NaN         Canada  56.1304 -106.3468        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  9/25/20  9/26/20  9/27/20  \
# 39        0        0        0        0  ...   131709   132253   133204
#
#     9/28/20  9/29/20  9/30/20  10/1/20  10/2/20  10/3/20  10/4/20
# 39   134551   135765   137181   138548   139817   140711   142502
#
# [1 rows x 261 columns]

# %%
# Transform from wide to long format table
df_confirmed = pd.melt(df_confirmed, id_vars=df_confirmed.columns[:4], 
                    value_vars = df_confirmed.columns[4:], 
                    var_name = 'date', 
                    value_name = 'confirmed')
df_confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long     date  confirmed
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20          0
# 1            NaN        Albania  41.15330  20.168300  1/22/20          0
# 2            NaN        Algeria  28.03390   1.659600  1/22/20          0
# 3            NaN        Andorra  42.50630   1.521800  1/22/20          0
# 4            NaN         Angola -11.20270  17.873900  1/22/20          0

# %%
# Transform from wide to long format table
df_deaths = pd.melt(df_deaths, id_vars=df_deaths.columns[:4], 
                    value_vars = df_deaths.columns[4:], 
                    var_name = 'date', 
                    value_name = 'deaths')

# %%
# Transform from wide to long format table
df_recovered = pd.melt(df_recovered, id_vars=df_recovered.columns[:4], 
                    value_vars = df_recovered.columns[4:], 
                    var_name = 'date', 
                    value_name = 'recovered')

# %%
# Check the size of the each of the three dataframe
print(df_confirmed.shape)
print(df_deaths.shape)
print(df_recovered.shape)
# Out:
# (68362, 6)
# (68362, 6)
# (65021, 6)

# %%
# Summarize confirmed and deaths data by date
df_confirmed_canada = df_confirmed[df_confirmed['Country/Region'] == 'Canada'].groupby('date').sum()[['confirmed']]
df_deaths_canada = df_deaths[df_deaths['Country/Region'] == 'Canada'].groupby('date').sum()[['deaths']]

# Extract columns from recoveries table (drop the last deaths value column)
df_recovered_canada = df_recovered[df_recovered['Country/Region'] == 'Canada']
df_canada_template  = df_recovered_canada[df_recovered_canada.columns[:-1]].reset_index(drop=True)

# Join aggrregated confirmed and deaths data with extracted columns
df_confirmed_canada = df_canada_template.merge(df_confirmed_canada, how='inner', left_on='date', right_index=True)
df_deaths_canada = df_canada_template.merge(df_deaths_canada, how='inner', left_on='date', right_index=True)

# Add the agrregated data for Canada back to confirmed and deaths table
df_confirmed = df_confirmed[df_confirmed['Country/Region'] != 'Canada'].append(df_confirmed_canada)
df_deaths = df_deaths[df_deaths['Country/Region'] != 'Canada'].append(df_deaths_canada)

# %%
df_recovered.head()
# Out:
#   Province/State Country/Region       Lat       Long     date  recovered
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20          0
# 1            NaN        Albania  41.15330  20.168300  1/22/20          0
# 2            NaN        Algeria  28.03390   1.659600  1/22/20          0
# 3            NaN        Andorra  42.50630   1.521800  1/22/20          0
# 4            NaN         Angola -11.20270  17.873900  1/22/20          0

# %%
# Merge the three table together
df_data = df_confirmed.merge(df_deaths, how='inner', on=['Country/Region','Province/State','date'])
df_data = df_data.merge(df_recovered, how='inner', on=['Country/Region','Province/State','date'])

# %%
df_data.head()
# Out:
#   Province/State Country/Region     Lat_x     Long_x     date  confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  1/22/20          0
# 1            NaN        Albania  41.15330  20.168300  1/22/20          0
# 2            NaN        Algeria  28.03390   1.659600  1/22/20          0
# 3            NaN        Andorra  42.50630   1.521800  1/22/20          0
# 4            NaN         Angola -11.20270  17.873900  1/22/20          0
#
#       Lat_y     Long_y  deaths       Lat       Long  recovered
# 0  33.93911  67.709953       0  33.93911  67.709953          0
# 1  41.15330  20.168300       0  41.15330  20.168300          0
# 2  28.03390   1.659600       0  28.03390   1.659600          0
# 3  42.50630   1.521800       0  42.50630   1.521800          0
# 4 -11.20270  17.873900       0 -11.20270  17.873900          0

# %%
# Drop the columns 
df_data = df_data.drop(['Lat_x','Lat_y','Long_x','Long_y'],axis=1)

# %%
df_data.head()
# Out:
#   Province/State Country/Region     date  confirmed  deaths       Lat  \
# 0            NaN    Afghanistan  1/22/20          0       0  33.93911
# 1            NaN        Albania  1/22/20          0       0  41.15330
# 2            NaN        Algeria  1/22/20          0       0  28.03390
# 3            NaN        Andorra  1/22/20          0       0  42.50630
# 4            NaN         Angola  1/22/20          0       0 -11.20270
#
#         Long  recovered
# 0  67.709953          0
# 1  20.168300          0
# 2   1.659600          0
# 3   1.521800          0
# 4  17.873900          0

# %%
# Get the population of the county data
url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/UID_ISO_FIPS_LookUp_Table.csv"
df_pop = pd.read_csv( url )

# %%
df_pop.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2 Province_State Country_Region       Lat  \
# 0    4   AF  AFG    4.0   NaN    NaN            NaN    Afghanistan  33.93911
# 1    8   AL  ALB    8.0   NaN    NaN            NaN        Albania  41.15330
# 2   12   DZ  DZA   12.0   NaN    NaN            NaN        Algeria  28.03390
# 3   20   AD  AND   20.0   NaN    NaN            NaN        Andorra  42.50630
# 4   24   AO  AGO   24.0   NaN    NaN            NaN         Angola -11.20270
#
#        Long_ Combined_Key  Population
# 0  67.709953  Afghanistan  38928341.0
# 1  20.168300      Albania   2877800.0
# 2   1.659600      Algeria  43851043.0
# 3   1.521800      Andorra     77265.0
# 4  17.873900       Angola  32866268.0

# %%
# Check if the name of Country matchs in two tables
for c in df_data['Country/Region'].unique():
  if c not in df_pop['Country_Region'].unique():
    print(c)

# %%
# rename the column name
df_data = df_data.rename(columns={"Country/Region":"Country_Region","Province/State": "Province_State"})

# %%
df_data1 = df_data.merge(df_pop[['Country_Region','Province_State','Population']], how='inner', on=['Country_Region','Province_State'])

# %%
df_data1[df_data1.Population.isnull()].Country_Region
# Out:
# 22616    Diamond Princess
# 22617    Diamond Princess
# 22618    Diamond Princess
# 22619    Diamond Princess
# 22620    Diamond Princess
# 22621    Diamond Princess
# 22622    Diamond Princess
# 22623    Diamond Princess
# 22624    Diamond Princess
# 22625    Diamond Princess
# 22626    Diamond Princess
# 22627    Diamond Princess
# 22628    Diamond Princess
# 22629    Diamond Princess
# 22630    Diamond Princess
# 22631    Diamond Princess
# 22632    Diamond Princess
# 22633    Diamond Princess
# 22634    Diamond Princess
# 22635    Diamond Princess
# 22636    Diamond Princess
# 22637    Diamond Princess
# 22638    Diamond Princess
# 22639    Diamond Princess
# 22640    Diamond Princess
# 22641    Diamond Princess
# 22642    Diamond Princess
# 22643    Diamond Princess
# 22644    Diamond Princess
# 22645    Diamond Princess
#                ...
# 39805          MS Zaandam
# 39806          MS Zaandam
# 39807          MS Zaandam
# 39808          MS Zaandam
# 39809          MS Zaandam
# 39810          MS Zaandam
# 39811          MS Zaandam
# 39812          MS Zaandam
# 39813          MS Zaandam
# 39814          MS Zaandam
# 39815          MS Zaandam
# 39816          MS Zaandam
# 39817          MS Zaandam
# 39818          MS Zaandam
# 39819          MS Zaandam
# 39820          MS Zaandam
# 39821          MS Zaandam
# 39822          MS Zaandam
# 39823          MS Zaandam
# 39824          MS Zaandam
# 39825          MS Zaandam
# 39826          MS Zaandam
# 39827          MS Zaandam
# 39828          MS Zaandam
# 39829          MS Zaandam
# 39830          MS Zaandam
# 39831          MS Zaandam
# 39832          MS Zaandam
# 39833          MS Zaandam
# 39834          MS Zaandam
# Name: Country_Region, Length: 514, dtype: object

# %%
df_data1.to_csv('covid19_confirmed_deaths_recovered_global.csv',index=False)

# %%
test = pd.read_csv('covid19_confirmed_deaths_recovered_global.csv' )

# %%
test.head()
# Out:
#   Province_State Country_Region     date  confirmed  deaths       Lat  \
# 0            NaN    Afghanistan  1/22/20          0       0  33.93911
# 1            NaN    Afghanistan  1/23/20          0       0  33.93911
# 2            NaN    Afghanistan  1/24/20          0       0  33.93911
# 3            NaN    Afghanistan  1/25/20          0       0  33.93911
# 4            NaN    Afghanistan  1/26/20          0       0  33.93911
#
#         Long  recovered  Population
# 0  67.709953          0  38928341.0
# 1  67.709953          0  38928341.0
# 2  67.709953          0  38928341.0
# 3  67.709953          0  38928341.0
# 4  67.709953          0  38928341.0
